# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\Mohana\Desktop\DE ML\forestfires.csv")


from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

data['month'] = le.fit_transform(data['month'])
data['day'] = le.fit_transform(data['day'])

x = data.iloc[ :, :-1]
y = data.iloc[ :, -1]

from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain,  ytest = train_test_split(x, y, test_size = 0.3, random_state = 52)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)

ypred = model.predict(xtest)


from sklearn.metrics import mean_squared_error
error = mean_squared_error(ytest, ypred)
print(error ** 0.5)  #Root Mean Squared Error
# Out:
# 26.979312132100688
